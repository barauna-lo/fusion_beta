# %% [markdown]
# # POC 01 — Local/Colab output generation
#
# Install the dependencies and run the minimal experiment.

# %%
# !pip install -q colorednoise==2.2.0 pandas pyarrow matplotlib plotly

# %%
from pathlib import Path
from experiment import run_experiment

artifacts = run_experiment(
    n_points=2042,
    seed=42,
    output_uri=Path('outputs'),
    storage_backend='local',
)
artifacts

# %%
import pandas as pd
df = pd.read_parquet(artifacts['parquet'])
df.head()
